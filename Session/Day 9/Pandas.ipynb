# %% [markdown]
# # Session 9: Pandas
#
# Welcome to the first hour of the session on Pandas Series. In this section, we will cover the basics of Pandas and an introduction to Pandas Series.

# %% [markdown]
# ## What is Pandas?
#
# Pandas is a powerful Python library used for data manipulation and analysis. It provides data structures like **Series** and **DataFrame** to handle labeled and relational data efficiently. Pandas is widely used in data science and machine learning workflows.
#
# **Key Features of Pandas:**
# - Fast and efficient data manipulation
# - Integrated handling of missing data
# - Alignment of data for operations
# - Data visualization support

# %%
# Install and import Pandas
import pandas as pd
print('Pandas version:', pd.__version__)
# Out:
# Pandas version: 2.3.3

# %% [markdown]
# ## Introduction to Pandas Series
#
# A **Pandas Series** is a one-dimensional labeled array capable of holding any data type. It is similar to a column in a spreadsheet but more powerful due to its labels (index).
#
# **Key Characteristics:**
# - Homogeneous data (all elements of the same type).
# - Labeled index (row labels).
# - Supports various data types (integers, floats, strings, etc.).
#
# **Creating a Series:**

# %%
# Creating a Pandas Series
import pandas as pd

# Creating a Series from a list
data = [10, 20, 30, 40, 50]
series = pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# ### Attributes of a Series
#
# - **index**: Returns the index (row labels).
# - **values**: Returns the data values.
# - **dtype**: Returns the data type of elements in the Series.

# %%
# Exploring Series attributes
print('Index:', series.index)
print('Values:', series.values)
print('Data Type:', series.dtype)
# Out:
# Index: RangeIndex(start=0, stop=5, step=1)
# Values: [10 20 30 40 50]
# Data Type: int64

# %% [markdown]
# ### Creating a Series with Custom Indices
#
# You can assign custom labels to the indices when creating a Series. This makes data access easier and more intuitive.

# %%
# Creating a Series with custom indices
data = [100, 200, 300]
labels = ['a', 'b', 'c']
custom_series = pd.Series(data, index=labels)
print(custom_series)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %% [markdown]
# ## Accessing Elements in a Series
#
# You can access elements in a Series using:
# - **Index labels**: Use the custom or default index.
# - **Integer indices**: Similar to lists in Python.
#
# **Examples:**

# %%
# Accessing elements
print('Element with index a:', custom_series['a'])
print('Element at position 1:', custom_series[1])
# Out:
# Element with index a: 100
# Element at position 1: 200
# C:\Users\HP\AppData\Local\Temp\ipykernel_22136\1212875187.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Element at position 1:', custom_series[1])

# %% [markdown]
# ## Basic Operations on Series
#
# Pandas Series supports various operations:
# - Element-wise operations (e.g., addition, multiplication).
# - Applying NumPy functions.
# - Filtering based on conditions.

# %%
import numpy as np
# Basic operations on Series
series = pd.Series([1, 2, 3, 4, 5])
print('Original Series:\n', series)

# Element-wise operations
print('\nSeries + 10:\n', series + 10)
print('\nSeries * 2:\n', series * 2)

# Applying a NumPy function
print('\nSquare root:\n', np.sqrt(series))
print(np.pow(series,3))
# Out:
# Original Series:
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#
# Series + 10:
#  0    11
# 1    12
# 2    13
# 3    14
# 4    15
# dtype: int64
#
# Series * 2:
#  0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
#
# Square root:
#  0    1.000000
# 1    1.414214
# 2    1.732051
# 3    2.000000
# 4    2.236068
# dtype: float64
# 0      1
# 1      8
# 2     27
# 3     64
# 4    125
# dtype: int64

# %% [markdown]
# ## Exercise
#
# 1. Create a Pandas Series from a dictionary where keys are student names and values are their scores.
# 2. Find the mean score.
# 3. Access the score of a specific student using their name as the index.
# 4. Multiply all scores by 1.1 to add a 10% bonus.

# %% [markdown]
# ## Series Methods
#
# Pandas Series comes with a variety of built-in methods to make data manipulation easier. Here are some commonly used methods:
#
# - **`head()`**: Displays the first n rows.
# - **`tail()`**: Displays the last n rows.
# - **`describe()`**: Provides summary statistics.
# - **`value_counts()`**: Counts unique values.
# - **`sort_values()`**: Sorts the Series.
# - **`apply()`**: Applies a function to each element in the Series.
#
# Let's explore these methods with examples.

# %%
# Sample Series
data = [50, 20, 30, 40, 10]
labels = ['a', 'b', 'c', 'd', 'e']
series = pd.Series(data, index=labels)
print(series)

# Using Series methods
print('First 3 elements:\n', series.head(3))
print('\nLast 2 elements:\n', series.tail(2))
print('\nSummary statistics:\n', series.describe())
# Out:
# a    50
# b    20
# c    30
# d    40
# e    10
# dtype: int64
# First 3 elements:
#  a    50
# b    20
# c    30
# dtype: int64
#
# Last 2 elements:
#  d    40
# e    10
# dtype: int64
#
# Summary statistics:
#  count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %%
# Counting unique values and sorting
data = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']
series = pd.Series(data)

print('Value counts:\n', series.value_counts())
print('\nSorted values:\n', series.sort_values())
# Out:
# Value counts:
#  apple     3
# banana    2
# orange    1
# Name: count, dtype: int64
#
# Sorted values:
#  0     apple
# 2     apple
# 5     apple
# 1    banana
# 4    banana
# 3    orange
# dtype: object

# %% [markdown]
# ### Applying Functions with `apply()`
#
# The `apply()` method allows you to apply custom or built-in functions to each element in the Series.

# %%
# Using apply() to apply a lambda function
series = pd.Series([1, 2, 3, 4, 5])
print('Original Series:\n', series)

# Squaring each element
squared = series.apply(lambda x: x ** 2)
print('\nSquared Series:\n', squared)
# Out:
# Original Series:
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#
# Squared Series:
#  0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64

# %% [markdown]
# ## Series with Python Functionalities
#
# Pandas Series can be combined with native Python functionalities for tasks such as:
# - Iterating through elements.
# - Performing mathematical operations.
# - Using conditionals.
#
# Let's look at some examples:

# %%
# Iterating through a Series
series = pd.Series([10, 20, 30, 40])
for value in series:
    print('Value:', value)
# Out:
# Value: 10
# Value: 20
# Value: 30
# Value: 40

# %%
# Using conditionals
series = pd.Series([10, 20, 30, 40])

# Elements greater than 20
filtered = series[series > 20]
print('Filtered Series:\n', filtered)
# Out:
# Filtered Series:
#  2    30
# 3    40
# dtype: int64

# %% [markdown]
# ## Boolean Indexing on Series
#
# Boolean indexing allows you to filter data based on conditions. It returns a subset of the Series where the condition is `True`.
#
# **Examples of Boolean Indexing:**

# %%
# Boolean indexing example
series = pd.Series([10, 15, 20, 25, 30])

# Condition: Values greater than 20
print('Values greater than 20:\n', series[series > 20])
# Out:
# Values greater than 20:
#  3    25
# 4    30
# dtype: int64

# %% [markdown]
# ### Compound Conditions
#
# You can combine multiple conditions using logical operators such as:
# - **`&`**: Logical AND
# - **`|`**: Logical OR
#
# For example:

# %%
# Compound condition example
series = pd.Series([10, 15, 20, 25, 30])

# Condition: Values greater than 10 and less than 30
filtered = series[(series > 10) & (series < 30)]
print('Filtered values:\n', filtered)
# Out:
# Filtered values:
#  1    15
# 2    20
# 3    25
# dtype: int64

# %% [markdown]
# ## Exercise
#
# 1. Create a Series of random integers between 1 and 50 (10 elements).
# 2. Use boolean indexing to find all elements greater than 25.
# 3. Apply a function to subtract 5 from each of these elements.
# 4. Sort the resulting Series in descending order.

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Load a dataset
import pandas as pd
df = pd.read_csv(r'D:\ML Course\Day 9\series.csv')
df
# Out:
#    Index    Name  Marks
# 0      0   Akash  10.00
# 1      1  Batash  20.00
# 2      2   pahar  30.00
# 3      3  Shobuj  10.00
# 4      4   Sagor  50.00
# 5      5    Nodi  70.00
# 6      6   Pukur  55.45
# 7      7    Duba  70.00

# %%
df.head(6)
# Out:
#    Index    Name  Marks
# 0      0   Akash   10.0
# 1      1  Batash   20.0
# 2      2   pahar   30.0
# 3      3  Shobuj   10.0
# 4      4   Sagor   50.0
# 5      5    Nodi   70.0

# %%
df.tail()
# Out:
#    Index    Name  Marks
# 3      3  Shobuj  10.00
# 4      4   Sagor  50.00
# 5      5    Nodi  70.00
# 6      6   Pukur  55.45
# 7      7    Duba  70.00

# %%
df.describe()
# Out:
#          Index      Marks
# count  8.00000   8.000000
# mean   3.50000  39.431250
# std    2.44949  25.174008
# min    0.00000  10.000000
# 25%    1.75000  17.500000
# 50%    3.50000  40.000000
# 75%    5.25000  59.087500
# max    7.00000  70.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   8 non-null      int64
#  1   Name    8 non-null      object
#  2   Marks   8 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 324.0+ bytes

# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40, 50])
print(s)

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Paris', 'London']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London

# %%
df2 = pd.read_csv("students.csv")   # suppose you already have a CSV file
print(df2.head())   # shows first 5 rows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df2 = pd.read_csv("students.csv")   # suppose you already have a CSV file
#       2 print(df2.head())   # shows first 5 rows
#
# File d:\ML Course\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File d:\ML Course\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File d:\ML Course\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File d:\ML Course\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File d:\ML Course\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'students.csv'

# %%
print(df['Name'])         # select one column
print(df[['Name','Age']]) # select multiple columns
print(df.iloc[0])         # select first row by index position
print(df.loc[1])          # select row with index = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df['Name'])         # select one column
#       2 print(df[['Name','Age']]) # select multiple columns
#       3 print(df.iloc[0])         # select first row by index position
#
# NameError: name 'df' is not defined

# %%
print(df[df['Age'] > 30])

# %%
df['Country'] = ['USA', 'France', 'UK']
print(df)

# %%
print(df.describe())     # summary statistics
print(df['Age'].mean())  # average of Age column

# %%
print(df.sort_values(by='Age', ascending=False))

# %%
df.to_csv("output.csv", index=False)

# %% [markdown]
# ## Introduction to Data Visualization
#
# Data visualization is a crucial step in data analysis as it helps to:
# - Summarize large datasets visually.
# - Identify trends, patterns, and outliers.
# - Communicate insights effectively.
#
# We'll use two powerful libraries:
#
# - **Matplotlib**: A versatile library for creating static, animated, and interactive visualizations.
# - **Seaborn**: Built on top of Matplotlib, it provides a high-level interface for drawing attractive statistical graphics.

# %% [markdown]
# ## Plotting with Matplotlib
#
# Matplotlib provides a simple interface to create visualizations from Pandas Series. Here are some commonly used plot types:
#
# - **Line plot**: Useful for continuous data.
# - **Bar plot**: Ideal for categorical data.
# - **Histogram**: Displays the distribution of data.
#
# Let's explore these plots with examples.

# %%
df
# Out:
#    Index    Name  Marks
# 0      0   Akash  10.00
# 1      1  Batash  20.00
# 2      2   pahar  30.00
# 3      3  Shobuj  10.00
# 4      4   Sagor  50.00
# 5      5    Nodi  70.00
# 6      6   Pukur  55.45
# 7      7    Duba  70.00

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv(r"D:\ML Course\Day 9\series.csv")
print(df)

# Line plot
plt.figure(figsize=(16, 8))
df.plot(kind='line', title='Line Plot')
plt.xlabel('Category')
plt.ylabel('Value')
plt.show()
# Out:
#    Index    Name  Marks
# 0      0   Akash  10.00
# 1      1  Batash  20.00
# 2      2   pahar  30.00
# 3      3  Shobuj  10.00
# 4      4   Sagor  50.00
# 5      5    Nodi  70.00
# 6      6   Pukur  55.45
# 7      7    Duba  70.00

# %%
# Bar plot
plt.figure(figsize=(8, 4))
df.plot(kind='bar', color='skyblue', title='Bar Plot')
plt.xlabel('Category')
plt.ylabel('Value')
plt.show()

# %%
plt.figure(figsize=(8, 4))
df["Marks"].plot(kind='bar', color='skyblue', title='Bar Plot')
plt.xlabel('Category')
plt.ylabel('Value')
plt.show()

# %%
df[["Marks","Index"]].plot(kind="bar",title="Bar plot")
plt.Figure(figsize=(16,10))
plt.xlabel("Demo")
plt.ylabel("ylebel")
plt.show()

# %%
df.plot(x="Index",y="Marks",title="title of the bar plot",kind='bar')
plt.xlabel("x axix")
plt.ylabel("Y label")
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 4))
df['Marks'].plot(kind='hist', bins=3, color='green', title='Histogram')
plt.xlabel('Value')
plt.show()

# %% [markdown]
# ### Enhancing Visualizations
#
# You can customize Matplotlib plots by adding features like:
# - Titles and labels
# - Grid lines
# - Annotations
#
# Example:

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
df['Marks'].plot(kind='pie', title='Enhanced Line Plot', color='purple')
plt.xlabel('Category')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 8))  # square figure
df['Marks'].plot(
    kind='pie',
    autopct='%1.1f%%',       # show percentages
    colors=['red','green','blue','orange','purple'],  # multiple colors
    title='Pie Chart of Marks'
)
plt.ylabel('')   # remove y-label (not needed for pie)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, color='blue', marker='o')
plt.title("Line Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
categories = ["A", "B", "C", "D"]
values = [4, 7, 2, 9]

plt.bar(categories, values, color='green')
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
data = [7, 8, 5, 6, 3, 4, 8, 6, 7, 9, 5, 6, 4, 5]

plt.hist(data, bins=5, color='purple', edgecolor='black')
plt.title("Histogram Example")
plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.show()

# %%
x = [5, 7, 8, 7, 6, 9, 5, 6, 7, 8]
y = [99, 86, 87, 88, 100, 86, 103, 87, 94, 78]

plt.scatter(x, y, color='red')
plt.title("Scatter Plot Example")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %%
sizes = [30, 20, 25, 25]
labels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(sizes, labels=labels, autopct="%1.1f%%", startangle=90)
plt.title("Pie Chart Example")
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [1, 4, 9, 16, 25]

plt.subplot(1, 2, 1)   # 1 row, 2 columns, plot 1
plt.plot(x, y1, 'b-o')
plt.title("Linear")

plt.subplot(1, 2, 2)   # 1 row, 2 columns, plot 2
plt.plot(x, y2, 'r--s')
plt.title("Quadratic")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plotting with Seaborn
#
# Seaborn makes it easy to create informative and attractive visualizations. Commonly used plots for Series include:
#
# - **Barplot**
# - **KDE Plot** (Kernel Density Estimate)
#
# Let's explore these plots.

# %%
import seaborn as sns

# Barplot using Seaborn
sns.barplot(x=df.Name, y=df.Marks, palette='coolwarm')
plt.title('Marks by Name')
plt.xlabel('Name')
plt.ylabel('Marks')
plt.show()
# Out:
# C:\Users\Shaiful\AppData\Local\Temp\ipykernel_23764\2305290057.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df.Name, y=df.Marks, palette='coolwarm')

# %%
# KDE Plot
sns.kdeplot(df, shade=True, color='orange')
plt.title('KDE Plot')
plt.xlabel('Value')
plt.show()
# Out:
# C:\Users\Shaiful\AppData\Local\Temp\ipykernel_23764\3207140973.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df, shade=True, color='orange')

# %% [markdown]
# ## Exercise
#
# 1. Create a Pandas Series with random data (10 elements).
# 2. Plot the following visualizations:
#    - Line Plot
#    - Bar Plot
#    - KDE Plot
# 3. Enhance at least one of the visualizations by adding labels, titles, and custom colors.
# 4. Save one of the plots as an image file using `plt.savefig()`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = sns.load_dataset("tips")   # restaurant tips dataset
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=df.total_bill, y=df.tip)
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip",data=df)
plt.show()

# %%
sns.histplot(df['total_bill'], bins=20, kde=True)
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", data=df)
plt.show()

# %%
sns.countplot(x="day", data=df)
plt.show()

# %%
corr = df.corr(numeric_only=True)   # correlation matrix
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
sns.pairplot(df, hue="sex")
plt.show()
